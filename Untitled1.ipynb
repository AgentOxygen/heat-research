# %%
import xarray
HEAD_DATA_DIR = "/projects/dgs/persad_research/heat_research/data/"

xarray.open_dataset(HEAD_DATA_DIR + "MERRA2/downloads/MERRA2_1980-2015.nc")
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 13149, lat: 361, lon: 576)
# Coordinates:
#   * lat      (lat) float64 -90.0 -89.5 -89.0 -88.5 -88.0 ... 88.5 89.0 89.5 90.0
#   * lon      (lon) float64 -180.0 -179.4 -178.8 -178.1 ... 178.1 178.8 179.4
#   * time     (time) datetime64[ns] 1980-01-01T12:00:00 ... 2015-12-31T12:00:00
# Data variables:
#     T2MMAX   (time, lat, lon) float32 ...
#     T2MMIN   (time, lat, lon) float32 ...
# Attributes: (12/34)
#     CDI:                               Climate Data Interface version 1.6.9 (...
#     history:                           Thu Feb 18 18:14:38 2016: ncks -3 MERR...
#     Conventions:                       CF-1
#     nco_openmp_thread_number:          1
#     Comment:                           GMAO filename: d5124_m2_jan79.statD_2d...
#     History:                           Original file generated: Sat May 31 17...
#     ...                                ...
#     RangeBeginningDate:                1980-01-01
# ...
