# %%
import xarray
import xesmf as xe
import numpy as np
from paths import heat_out_trefht_tmax_members_1920_1950_CONTROL as data_paths

variable = "HWF"
exp_num = "3136"
min_max = "tx"

member_paths = [path for path in data_paths()[0] if exp_num in path]

heat_data = xarray.open_mfdataset(member_paths, concat_dim="member", combine="nested")[f"{variable}_{min_max}90"].dt.days.mean(dim="member")

# %%
pop_data = xarray.open_rasterio("ppp_2020_1km_Aggregated.tif").rename({"x":"lon", "y":"lat"})
np.sum(pop_data.where(pop_data > 0))
# Out:
# <xarray.DataArray ()>
# array(7.9694013e+09, dtype=float32)

# %%
lat_delta = (shift_heat_data.lat.values[1] - shift_heat_data.lat.values[0]) / 2
lon_delta = (shift_heat_data.lon.values[1] - shift_heat_data.lon.values[0]) / 2
lats = np.append(shift_heat_data.lat.values - lat_delta, shift_heat_data.lat.values[-1::])
lons = np.append(shift_heat_data.lon.values - lon_delta, shift_heat_data.lon.values[-1::])

# %%
shift_heat_data = heat_data.assign_coords(lon=(((heat_data.lon + 180) % 360) - 180)).sortby('lon')
resampled_data = pop_data.where(pop_data > 0).astype(np.float64).groupby_bins("lat", lats).sum().groupby_bins("lon", lons).sum()
resampled_data.plot()

# %%
heat_data.mean(dim="time").plot()

# %%
new_data = resampled_data.rename({"lat_bins":"lon", "lon_bins":"lat"}).mean(dim="band")

# %%
error = new_data.sum(dim="lat").sum(dim="lon") - np.sum(pop_data.where(pop_data > 0))
error
# Out:
# <xarray.DataArray ()>
# array(95238.0175457)

# %%
perc_data = new_data / np.max(new_data)
perc_data.plot()

# %%
perc_data = (new_data / new_data.sum(dim="lat").sum(dim="lon"))

# %%
weighted_data = np.multiply(new_data.values, shift_heat_data.sel(time=2021).values)

# %%
weighted_new = shift_heat_data.groupby("time").apply(lambda data: np.multiply(perc_data.values, data.values))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_110721/1379884320.py in <module>
# ----> 1 weighted_new = shift_heat_data.groupby("time").apply(lambda data: np.multiply(perc_data.values, data.values))
#
# NameError: name 'shift_heat_data' is not defined

# %%
weighted_data[weighted_data == 0] = np.nan
np.nanmean(weighted_data)
# Out:
# 0.0010191078847343999

# %%
shift_heat_data.sel(time=2021).plot()

# %%
xarray.DataArray(weighted_data, coords=shift_heat_data.mean(dim="time").coords).plot(vmax=4000000)

# %%
xarray.DataArray(weighted_data, coords=heat_data.mean(dim="time").coords).plot()

# %%
np.max(weighted_data)
# Out:
# 72.34959059193363

# %%
np.max(heat_data.mean(dim="time").values)
# Out:
# 83.94031250000002
