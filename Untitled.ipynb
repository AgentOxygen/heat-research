# %%
import intake
import s3fs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-261ce9b370a0> in <module>
#       1 import intake
# ----> 2 import s3fs
#
# /projects/dgs/rh5_local/anaconda/climate/lib/python3.8/site-packages/s3fs/__init__.py in <module>
# ----> 1 from .core import S3FileSystem, S3File
#       2 from .mapping import S3Map
#       3
#       4 from ._version import get_versions
#       5
#
# /projects/dgs/rh5_local/anaconda/climate/lib/python3.8/site-packages/s3fs/core.py in <module>
#       9 from fsspec.spec import AbstractBufferedFile
#      10 from fsspec.utils import infer_storage_options, tokenize
# ---> 11 from fsspec.asyn import AsyncFileSystem, sync, sync_wrapper, maybe_sync
#      12
#      13 import aiobotocore
#
# ImportError: cannot import name 'maybe_sync' from 'fsspec.asyn' (/projects/dgs/rh5_local/anaconda/climate/lib/python3.8/site-packages/fsspec/asyn.py)

# %%
col = intake.open_esm_datastore("https://ncar-cesm-lens.s3-us-west-2.amazonaws.com/catalogs/aws-cesm1-le.json")
col.df.head()
# Out:
#   variable                                long_name component experiment  \
# 0     FLNS             net longwave flux at surface       atm        20C
# 1    FLNSC    clearsky net longwave flux at surface       atm        20C
# 2     FLUT  upwelling longwave flux at top of model       atm        20C
# 3     FSNS                net solar flux at surface       atm        20C
# 4    FSNSC       clearsky net solar flux at surface       atm        20C
#
#   frequency  vertical_levels spatial_domain units           start_time  \
# 0     daily              1.0         global  W/m2  1920-01-01 12:00:00
# 1     daily              1.0         global  W/m2  1920-01-01 12:00:00
# 2     daily              1.0         global  W/m2  1920-01-01 12:00:00
# 3     daily              1.0         global  W/m2  1920-01-01 12:00:00
# 4     daily              1.0         global  W/m2  1920-01-01 12:00:00
#
#               end_time                                               path
# ...

# %%
col_subset = col.search(experiment="CTRL", frequency="daily", variable=["TREFHTMN", "TREFHTMX"])
col_subset
# Out:
# <p><strong>aws-cesm1-le catalog with 1 dataset(s) from 2 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>variable</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>long_name</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>component</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>experiment</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>vertical_levels</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>spatial_domain</th>
#       <td>1</td>
# ...

# %%
dsets = col_subset.to_dataset_dict(zarr_kwargs={"consolidated": True}, storage_options={"anon": True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'component.experiment.frequency'
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /projects/dgs/rh5_local/anaconda/climate/lib/python3.8/site-packages/fsspec/registry.py in get_filesystem_class(protocol)
#     210         try:
# --> 211             register_implementation(protocol, _import_class(bit["class"]))
#     212         except ImportError as e:
#
# /projects/dgs/rh5_local/anaconda/climate/lib/python3.8/site-packages/fsspec/registry.py in _import_class(cls, minv)
#     225
# --> 226     mod = importlib.import_module(mod)
#     227     if minversion:
#
# /projects/dgs/rh5_local/anaconda/climate/lib/python3.8/importlib/__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# ...
