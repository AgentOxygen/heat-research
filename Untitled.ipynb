# %%
import xarray
from os import listdir

# %%
DATA_DIR = "/home/persad_users/kmw3667/F_postprocessed/"
AER_1850_1850 = [DATA_DIR + "1850_1850aerosols/" + path for path in listdir(DATA_DIR + "1850_1850aerosols/")]
AER_1850_2000 = [DATA_DIR + "1850_2000aerosols/" + path for path in listdir(DATA_DIR + "1850_2000aerosols/")]
AER_1850_1850.sort()
AER_1850_2000.sort()

with xarray.set_options(keep_attrs=True):
    x = (xarray.open_mfdataset(AER_1850_1850) - xarray.open_mfdataset(AER_1850_2000))

# If things are slow after this, try doing this before any other calculations:
x = x.load()

# %%
import xarray
xarray.open_dataset("../data/autocorrelation/auto_all_min.nc")
# Out:
# <xarray.Dataset>
# Dimensions:          (lat: 192, lon: 288)
# Coordinates:
#   * lat              (lat) float64 -90.0 -89.06 -88.12 ... 88.12 89.06 90.0
#   * lon              (lon) float64 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
# Data variables:
#     Autocorrelation  (lat, lon) float64 ...
